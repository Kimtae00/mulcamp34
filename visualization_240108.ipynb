# %% [markdown]
# ## 라이브러리 불러오기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# tips 데이터 불러오기
tips = sns.load_dataset('tips')

# 도화지 그리기
fig, ax = plt.subplots()

# matplotlib 시각화
ax.plot([1, 2, 3])

# 산점도 그래프 그리기
# data : tips 라는 pandas DataFrame을 받는다
# x축 : '컬럼명' = total_bill
# y축 : '컬럼명' = tip

# ax는 seaborn과 matplotlib를 이어주는 매개변수 역할을 한다고 생각하면 된다.
# 모든 것이 제공해주는 것은 아니므로 확인을 해봐야 한다.
# ax.legend()로 범례를 만들어야 하는 것과는 달리 hue 옵션을 주기만 해도 범례가 만들어진다.
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex', ax = ax, data = tips) # seaborn 시각화

# output 폴더에 result.png로 그래프 저장하기
plt.savefig('output/result.png')

# 그래프 그리기
# 가장 마지막에 작성하는거 중요 !
plt.show()

# %% [markdown]
# ## matplotlib와 seaborn을 동시에 사용한 subplotting 기법
# - 다중차트를 하나의 도화지에 담기

# %%
# 도화지 그리기
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))

# 각 차트 위에 타이틀 지정하기
ax[0][0].set_title('ax[0][0] title')
ax[1][1].set_title('ax[1][1] title')
ax[0][1].set_title('ax[0][1] title')
ax[1][0].set_title('ax[1][0] title')

# 0,0 위치
ax[0][0].plot([1, 2, 3])

# 0,1 위치
x = np.arange(-5, 5, 0.1)
y1 = x**2 - 2
y2 = 20*np.cos(x)**2

ax[0][1].plot(x, y2)

# 1,0 위치
ax[1][0].plot(x, y1)

# 1,1 위치
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex', ax = ax[1][1], data = tips) # seaborn 시각화

# 가운데에 타이틀 지정
fig.suptitle('fig title', size=15)

# 간격 띄우기
plt.tight_layout()

# 그래프 출력하기
plt.show()

# %% [markdown]
# ## 산점도 그래프 : x축과 y축의 관계성을 파악하는 그래프
# - x축과 y축 데이터 형태가 연속형 데이터가 와야 함
# - 연속형 데이터의 예시 : 키, 몸무게 등 소수점이 존재하는 데이터

# %%
fig, ax=plt.subplots(1, 2, figsize=(15, 5))

# tip, total_bill
# 연속형 변수 : 숫자로 이루어진 데이터
# 소수점이 존재하는 데이터
sns.regplot(x="total_bill", y="tip", data=tips, ax=ax[0], fit_reg=True)
# 회귀선 그리기
ax[0].set_title('with linear regression line')

sns.regplot(x="total_bill", y="tip", data=tips, ax=ax[1], fit_reg=False)
ax[1].set_title('without linear regression line')

plt.show()

# %%
fig, ax = plt.subplots()
# sns.displot(x = 'tip', ax = ax, data = tips)
# 경고메시지 확인, ax 미존재
sns.displot(x = 'tip', ax = ax, data = tips)
plt.show()
# Out:
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2)

sns.boxplot(x = 'sex', y = 'tip', ax = ax[0], data = tips)
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex', ax = ax[1], data = tips)
plt.show()
# Out:
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2)

sns.boxplot(x = 'sex', y = 'tip', ax = ax[0], data = tips)
sns.swarmplot(x = 'sex', y ='tip', ax = ax[0], data = tips, alpha=2.5)
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex', ax = ax[1], data = tips)
plt.show()
# Out:
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 4
#       1 fig, ax = plt.subplots(nrows = 1, ncols = 2)
#       3 sns.boxplot(x = 'sex', y = 'tip', ax = ax[0], data = tips)
# ----> 4 sns.swarmplot(x = 'sex', y ='tip', ax = ax[0], data = tips, alpha=2.5)
#       5 sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex', ax = ax[1], data = tips)
#       6 plt.show()
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/categorical.py:2648, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2645 hue_order = p._palette_without_hue_backcompat(palette, hue_order)
#    2646 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
# -> 2648 color = _default_color(ax.scatter, hue, color, kwargs)
#    2650 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2652 # XXX Copying possibly bad default decisions from original code for now
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/utils.py:122, in _default_color(method, hue, color, kws)
#     116 scout_size = max(
#     117     np.atleast_1d(kws.get(key, [])).shape[0]
#     118     for key in ["s", "c", "fc", "facecolor", "facecolors"]
#     119 )
#     120 scout_x = scout_y = np.full(scout_size, np.nan)
# --> 122 scout = method(scout_x, scout_y, **kws)
#     123 facecolors = scout.get_facecolors()
#     125 if not len(facecolors):
#     126     # Handle bug in matplotlib <= 3.2 (I think)
#     127     # This will limit the ability to use non color= kwargs to specify
#     128     # a color in versions of matplotlib with the bug, but trying to
#     129     # work out what the user wanted by re-implementing the broken logic
#     130     # of inspecting the kwargs is probably too brittle.
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4741, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4735         linewidths = [
#    4736             lw if lw is not None else mpl.rcParams['lines.linewidth']
#    4737             for lw in linewidths]
#    4739 offsets = np.ma.column_stack([x, y])
# -> 4741 collection = mcoll.PathCollection(
#    4742     (path,), scales,
#    4743     facecolors=colors,
#    4744     edgecolors=edgecolors,
#    4745     linewidths=linewidths,
#    4746     offsets=offsets,
#    4747     offset_transform=kwargs.pop('transform', self.transData),
#    4748     alpha=alpha,
#    4749 )
#    4750 collection.set_transform(mtransforms.IdentityTransform())
#    4751 if colors is None:
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/collections.py:1027, in PathCollection.__init__(self, paths, sizes, **kwargs)
#    1013 def __init__(self, paths, sizes=None, **kwargs):
#    1014     """
#    1015     Parameters
#    1016     ----------
#    (...)
#    1024         Forwarded to `.Collection`.
#    1025     """
# -> 1027     super().__init__(**kwargs)
#    1028     self.set_paths(paths)
#    1029     self.set_sizes(sizes)
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/collections.py:203, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     200 self._offset_transform = offset_transform
#     202 self._path_effects = None
# --> 203 self._internal_update(kwargs)
#     204 self._paths = None
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/artist.py:1195, in Artist._update_props(self, props, errfmt)
#    1192             if not callable(func):
#    1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
# -> 1195             ret.append(func(v))
#    1196 if ret:
#    1197     self.pchanged()
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/collections.py:848, in Collection.set_alpha(self, alpha)
#     836 def set_alpha(self, alpha):
#     837     """
#     838     Set the transparency of the collection.
#     839
#    (...)
#     846         supported.
#     847     """
# --> 848     artist.Artist._set_alpha_for_array(self, alpha)
#     849     self._set_facecolor(self._original_facecolor)
#     850     self._set_edgecolor(self._original_edgecolor)
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/artist.py:1033, in Artist._set_alpha_for_array(self, alpha)
#    1031     raise TypeError("alpha must be numeric or None, not a string")
#    1032 if not np.iterable(alpha):
# -> 1033     Artist.set_alpha(self, alpha)
#    1034     return
#    1035 alpha = np.asarray(alpha)
#
# File ~/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/matplotlib/artist.py:1014, in Artist.set_alpha(self, alpha)
#    1011     raise TypeError(
#    1012         f'alpha must be numeric or None, not {type(alpha)}')
#    1013 if alpha is not None and not (0 <= alpha <= 1):
# -> 1014     raise ValueError(f'alpha ({alpha}) is outside 0-1 range')
#    1015 if alpha != self._alpha:
#    1016     self._alpha = alpha
#
# ValueError: alpha (2.5) is outside 0-1 range

# %%
# 막대 그래프 그리기
# countplot
sns.countplot(x = 'day', data = tips)
plt.show()
# Out:
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# 그래프를 내림차순으로 표현
sns.countplot(x = 'day', data = tips, order = tips['day'].value_counts().index)
plt.show()
# Out:
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ## 시각화 중급 레벨

# %% [markdown]
# ### 라이브러리 불러오기

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator, FuncFormatter) # 축 설정할 때 값
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 데이터 불러오기

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# y축 설정할 때, 값을 소수점 2자리까지 표현
def major_formatter(x, pos):
    return "%.2f$" % x
formatter = FuncFormatter(major_formatter)

# %% [markdown]
# ### 객체 지향 선언

# %%
# 몇 개의 그래프를 그릴지 정해야 함
# 2개를 그릴 예정
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5))

# 이상적인 막대 그래프
ax0 = sns.barplot(x = "day", y = 'total_bill', data = tips,
                  ci=None, color='lightgray', zorder=2, alpha=0.85, ax=ax[0]) 

group_mean = tips.groupby(['day'])['total_bill'].agg('mean')
h_day = group_mean.sort_values(ascending=False).index[0] # 해당되는 결괏값의 MAX값의 인덱스 요일을 하나 가져옴
h_mean = np.round(group_mean.sort_values(ascending=False)[0], 2) # 해당되는 결괏값의 MAX값을 하나 가져옴
for p in ax0.patches:
  fontweight = "normal"
  color = "k"
  height = np.round(p.get_height(), 2)
  if h_mean == height:
    fontweight="bold"
    color="darkred" # Adnobe Color Wheel 색상코드 추가
    p.set_facecolor(color)
    p.set_edgecolor("black")
  ax0.text(p.get_x() + p.get_width()/2., height+1, height, ha = 'center',
           size=12,
           fontweight=fontweight, color=color)

# y축 범위 지정 옵션
ax0.set_ylim(-3, 30)
ax0.set_title("Ideal Bar Graph", size = 16)

# 가로세로 축, 일부 수정 및 변경
ax0.spines['top'].set_visible(False)
ax0.spines['left'].set_position(("outward", 20))
ax0.spines['left'].set_visible(False)
ax0.spines['right'].set_visible(False)

# y축 값 변경
ax0.yaxis.set_major_locator(MultipleLocator(10))
ax0.yaxis.set_major_formatter(formatter)
ax0.yaxis.set_minor_locator(MultipleLocator(5))

# y축 라벨 변경
ax0.set_ylabel("Avg. Total Bill($)", fontsize=14)

# y축 Grid 라인 수정 
ax0.grid(axis="y", which="major", color="lightgray")
ax0.grid(axis="y", which="minor", ls=":")

# x축의 값을 변경
ax0.set_xlabel("Weekday", fontsize=14)
for xtick in ax0.get_xticklabels():
  print(xtick)
  if xtick.get_text() == h_day:
    xtick.set_color("darkred")
    xtick.set_fontweight("demibold")
ax0.set_xticklabels(['Thursday', 'Friday', 'Saturday', 'Sunday'], size=12)

# 그냥 일반 막대 그래프
ax1 = sns.barplot(x = "day", y = 'total_bill', data = tips,
                  errorbar=None, alpha=0.85,
                  ax=ax[1])
for p in ax1.patches:
  height = np.round(p.get_height(), 2)
  ax1.text(p.get_x() + p.get_width()/2., height+1, height, ha = 'center', size=12)
ax1.set_ylim(-3, 30)
ax1.set_title("Just Bar Graph")

# 그래프 그리기
plt.show()
# Out:
# /var/folders/kt/9_rb87_95nl_6glc6tz14j9m0000gn/T/ipykernel_20706/574109579.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax0 = sns.barplot(x = "day", y = 'total_bill', data = tips,
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /var/folders/kt/9_rb87_95nl_6glc6tz14j9m0000gn/T/ipykernel_20706/574109579.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_mean = tips.groupby(['day'])['total_bill'].agg('mean')
# /var/folders/kt/9_rb87_95nl_6glc6tz14j9m0000gn/T/ipykernel_20706/574109579.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   h_mean = np.round(group_mean.sort_values(ascending=False)[0], 2) # 해당되는 결괏값의 MAX값을 하나 가져옴
# /Users/gimtaegi/anaconda3/envs/mulcamp34/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0, 0, 'Thur')
# Text(1, 0, 'Fri')
# Text(2, 0, 'Sat')
# Text(3, 0, 'Sun')

# %%
# 각 그리드 선이 막대 그래프 위를 지나가므로 차트 뒤로 보내고 싶음
# zorder=2로 가능
